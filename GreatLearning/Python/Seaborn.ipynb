# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.tail(10)
# Out:
#      subject  timepoint event    region    signal
# 1054      s5          8   cue   frontal -0.028292
# 1055      s4          8   cue   frontal -0.160821
# 1056      s3          8   cue   frontal -0.033848
# 1057      s2          8   cue   frontal -0.069666
# 1058      s1          8   cue   frontal -0.136059
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899

# %%
sns.lineplot(x="timepoint",y='signal',data=fmri)
plt.show()

# %%
fmri.shape
# Out:
# (1064, 5)

# %%
fmri.size
# Out:
# 5320

# %%
sns.lineplot(x="timepoint",y='signal',data=fmri,hue='event')
plt.show()

# %%
sns.lineplot(x="timepoint",y='signal',data=fmri,hue='event',style='event')
plt.show()

# %%
sns.lineplot(x="timepoint",y='signal',data=fmri,hue='event',style='event',markers=True)
plt.show()

# %%
import pandas as pd

# %%
sns.set(style="whitegrid")
pkman=pd.read_csv("excel1.csv")

# %%
pkman.head()
# Out:
#    Emp_id        Dept  working years  Sales promotion using and  \
# 0  EMP001     FINANCE              5  72704                 yes
# 1  EMP002  OPERATIONS              4  44718                  no
# 2  EMP003       SALES              3  35210                  no
# 3  EMP004     FINANCE              5  30681                 yes
# 4  EMP005  OPERATIONS              6  47487                  no
#
#   promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                yes         NaN         NaN         NaN         NaN
# 1                 no         NaN         NaN         NaN         NaN
# 2                 no         NaN         NaN         NaN         NaN
# 3                yes         NaN         NaN         NaN         NaN
# 4                yes         NaN         NaN         NaN         NaN
#
#    Unnamed: 10    Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0          NaN            NaN         NaN         NaN
# 1          NaN  use of and/or         NaN         NaN
# ...

# %%
sns.barplot(x='Dept',y='Sales',data=pkman)
plt.show()

# %%
sns.barplot(x='Dept',y='working years',data=pkman)
plt.show()

# %%
sns.barplot(x='Dept',y='working years',data=pkman,hue="promotion using or")
plt.show()

# %%
sns.barplot(x='Dept',y='working years',data=pkman,hue="promotion using or",palette='vlag')
plt.show()

# %%
sns.barplot(x='Dept',y='working years',data=pkman,hue="promotion using or",palette='rocket')
plt.show()

# %%
sns.barplot(x='Dept',y='working years',data=pkman,hue="promotion using or",palette='vlag',color='g')
plt.show()

# %%
iris=pd.read_csv("excel1.csv")

# %%
iris.head()
# Out:
#    Emp_id        Dept  working years  Sales promotion using and  \
# 0  EMP001     FINANCE              5  72704                 yes
# 1  EMP002  OPERATIONS              4  44718                  no
# 2  EMP003       SALES              3  35210                  no
# 3  EMP004     FINANCE              5  30681                 yes
# 4  EMP005  OPERATIONS              6  47487                  no
#
#   promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                yes         NaN         NaN         NaN         NaN
# 1                 no         NaN         NaN         NaN         NaN
# 2                 no         NaN         NaN         NaN         NaN
# 3                yes         NaN         NaN         NaN         NaN
# 4                yes         NaN         NaN         NaN         NaN
#
#    Unnamed: 10    Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0          NaN            NaN         NaN         NaN
# 1          NaN  use of and/or         NaN         NaN
# ...

# %%
sns.scatterplot(x='working years',y='Sales',data=iris)
plt.show()

# %%
sns.barplot(x='Dept',y='working years',data=pkman,hue="promotion using and")
plt.show()

# %%
sns.distplot(iris['Sales'])
plt.show()
# Out:
# C:\Users\Surjith S Hanji\AppData\Local\Temp\ipykernel_26400\2913447896.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['Sales'])

# %%
sns.distplot(iris['Sales'],hist=False)
plt.show()
# Out:
# C:\Users\Surjith S Hanji\AppData\Local\Temp\ipykernel_26400\2056708634.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['Sales'],hist=False)

# %%
sns.distplot(iris['Sales'],color='g')
plt.show()
# Out:
# C:\Users\Surjith S Hanji\AppData\Local\Temp\ipykernel_26400\3493876363.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['Sales'],color='g')

# %%
sns.distplot(iris['Sales'],color='r',kde=False,bins=10)
plt.show()
# Out:
# C:\Users\Surjith S Hanji\AppData\Local\Temp\ipykernel_26400\899188113.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['Sales'],color='r',kde=False,bins=10)

# %%
sns.distplot(iris['Sales'],color='r',kde=False,bins=10,vertical=True)
plt.show()
# Out:
# C:\Users\Surjith S Hanji\AppData\Local\Temp\ipykernel_26400\2415720853.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['Sales'],color='r',kde=False,bins=10,vertical=True)

# %%
sns.jointplot(x='Sales',y='working years',data=iris)
plt.show()

# %%
sns.boxplot(x='Dept',y='Sales',data=iris)
plt.show()

# %%
iris.head()
# Out:
#    Emp_id        Dept  working years  Sales promotion using and  \
# 0  EMP001     FINANCE              5  72704                 yes
# 1  EMP002  OPERATIONS              4  44718                  no
# 2  EMP003       SALES              3  35210                  no
# 3  EMP004     FINANCE              5  30681                 yes
# 4  EMP005  OPERATIONS              6  47487                  no
#
#   promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                yes         NaN         NaN         NaN         NaN
# 1                 no         NaN         NaN         NaN         NaN
# 2                 no         NaN         NaN         NaN         NaN
# 3                yes         NaN         NaN         NaN         NaN
# 4                yes         NaN         NaN         NaN         NaN
#
#    Unnamed: 10    Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0          NaN            NaN         NaN         NaN
# 1          NaN  use of and/or         NaN         NaN
# ...
