# %%
import pandas as pd

# %%
s1=pd.Series([1,2,3,45])
print(s1)
# Out:
# 0     1
# 1     2
# 2     3
# 3    45
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1=pd.Series([1,2,3,45],index=['a','b','c','d'])
print(s1)
# Out:
# a     1
# b     2
# c     3
# d    45
# dtype: int64

# %%
d1=pd.Series({'a':10,'b':20,'c':30})
d1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
d1=pd.Series({'a':10,'b':20,'c':30},index=['c','a','b'])

# %%
d1
# Out:
# c    30
# a    10
# b    20
# dtype: int64

# %%
s1=pd.Series([1,2,3,45])
s1[0]
# s1[:]
# Out:
# 1

# %%
s1[:]
# Out:
# 0     1
# 1     2
# 2     3
# 3    45
# dtype: int64

# %%
s1[::-1]
# Out:
# 3    45
# 2     3
# 1     2
# 0     1
# dtype: int64

# %%
s1=pd.Series([1,2,3,45])
s1+5
# Out:
# 0     6
# 1     7
# 2     8
# 3    50
# dtype: int64

# %%
s1
# Out:
# 0     1
# 1     2
# 2     3
# 3    45
# dtype: int64

# %%
s1-100
# Out:
# 0   -99
# 1   -98
# 2   -97
# 3   -55
# dtype: int64

# %%
s1*5
# Out:
# 0      5
# 1     10
# 2     15
# 3    225
# dtype: int64

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Bob", "Sam", "Anne"],
    "Marks": [76, 25, 92]
})

print(df)
# Out:
#    name  Marks
# 0   Bob     76
# 1   Sam     25
# 2  Anne     92

# %%
iris=pd.read_csv('excel1.csv')

# %%
iris.head()
# Out:
#    Emp_id        Dept  working years  Sales promotion using and  \
# 0  EMP001     FINANCE              5  72704                 yes
# 1  EMP002  OPERATIONS              4  44718                  no
# 2  EMP003       SALES              3  35210                  no
# 3  EMP004     FINANCE              5  30681                 yes
# 4  EMP005  OPERATIONS              6  47487                  no
#
#   promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                yes         NaN         NaN         NaN         NaN
# 1                 no         NaN         NaN         NaN         NaN
# 2                 no         NaN         NaN         NaN         NaN
# 3                yes         NaN         NaN         NaN         NaN
# 4                yes         NaN         NaN         NaN         NaN
#
#    Unnamed: 10    Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0          NaN            NaN         NaN         NaN
# 1          NaN  use of and/or         NaN         NaN
# ...

# %%
iris.tail()
# Out:
#     Emp_id        Dept  working years   Sales promotion using and  \
# 7   EMP008     FINANCE              5   38966                 yes
# 8   EMP009  OPERATIONS              6   77052                  no
# 9   EMP010       SALES              2   86570                  no
# 10  EMP011       SALES              3   30250                  no
# 11  EMP012  OPERATIONS              7  100000                  no
#
#    promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 7                 yes         NaN         NaN         NaN         NaN
# 8                 yes         NaN         NaN         NaN         NaN
# 9                  no         NaN         NaN         NaN         NaN
# 10                 no         NaN         NaN         NaN         NaN
# 11                yes         NaN         NaN         NaN         NaN
#
#     Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13
# 7           NaN    finance           5>         yes
# ...

# %%
iris.head(20)
# Out:
#     Emp_id        Dept  working years   Sales promotion using and  \
# 0   EMP001     FINANCE              5   72704                 yes
# 1   EMP002  OPERATIONS              4   44718                  no
# 2   EMP003       SALES              3   35210                  no
# 3   EMP004     FINANCE              5   30681                 yes
# 4   EMP005  OPERATIONS              6   47487                  no
# 5   EMP006  OPERATIONS              2   75613                  no
# 6   EMP007       SALES              3   63671                  no
# 7   EMP008     FINANCE              5   38966                 yes
# 8   EMP009  OPERATIONS              6   77052                  no
# 9   EMP010       SALES              2   86570                  no
# 10  EMP011       SALES              3   30250                  no
# 11  EMP012  OPERATIONS              7  100000                  no
#
#    promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
iris.shape
# Out:
# (12, 14)

# %%
iris.size
# Out:
# 168

# %%
iris.describe()
# Out:
#        working years          Sales  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# count      12.000000      12.000000         0.0         0.0         0.0
# mean        4.250000   58576.833333         NaN         NaN         NaN
# std         1.658312   23708.108700         NaN         NaN         NaN
# min         2.000000   30250.000000         NaN         NaN         NaN
# 25%         3.000000   38027.000000         NaN         NaN         NaN
# 50%         4.500000   55579.000000         NaN         NaN         NaN
# 75%         5.250000   75972.750000         NaN         NaN         NaN
# max         7.000000  100000.000000         NaN         NaN         NaN
#
#        Unnamed: 9  Unnamed: 10
# count         0.0          0.0
# mean          NaN          NaN
# std           NaN          NaN
# min           NaN          NaN
# 25%           NaN          NaN
# 50%           NaN          NaN
# 75%           NaN          NaN
# max           NaN          NaN

# %%
iris.iloc[0:3,0:2]
# Out:
#    Emp_id        Dept
# 0  EMP001     FINANCE
# 1  EMP002  OPERATIONS
# 2  EMP003       SALES

# %%
iris.iloc[::-1,0:1]
# Out:
#     Emp_id
# 11  EMP012
# 10  EMP011
# 9   EMP010
# 8   EMP009
# 7   EMP008
# 6   EMP007
# 5   EMP006
# 4   EMP005
# 3   EMP004
# 2   EMP003
# 1   EMP002
# 0   EMP001

# %%
iris.loc[0:3,('Dept','Sales')]
# Out:
#          Dept  Sales
# 0     FINANCE  72704
# 1  OPERATIONS  44718
# 2       SALES  35210
# 3     FINANCE  30681

# %%
iris.drop('Sales',axis=1)
# Out:
#     Emp_id        Dept  working years promotion using and promotion using or  \
# 0   EMP001     FINANCE              5                 yes                yes
# 1   EMP002  OPERATIONS              4                  no                 no
# 2   EMP003       SALES              3                  no                 no
# 3   EMP004     FINANCE              5                 yes                yes
# 4   EMP005  OPERATIONS              6                  no                yes
# 5   EMP006  OPERATIONS              2                  no                 no
# 6   EMP007       SALES              3                  no                 no
# 7   EMP008     FINANCE              5                 yes                yes
# 8   EMP009  OPERATIONS              6                  no                yes
# 9   EMP010       SALES              2                  no                 no
# 10  EMP011       SALES              3                  no                 no
# ...

# %%
iris.drop([7,9],axis=0)
# Out:
#     Emp_id        Dept  working years   Sales promotion using and  \
# 0   EMP001     FINANCE              5   72704                 yes
# 1   EMP002  OPERATIONS              4   44718                  no
# 2   EMP003       SALES              3   35210                  no
# 3   EMP004     FINANCE              5   30681                 yes
# 4   EMP005  OPERATIONS              6   47487                  no
# 5   EMP006  OPERATIONS              2   75613                  no
# 6   EMP007       SALES              3   63671                  no
# 8   EMP009  OPERATIONS              6   77052                  no
# 10  EMP011       SALES              3   30250                  no
# 11  EMP012  OPERATIONS              7  100000                  no
#
#    promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                 yes         NaN         NaN         NaN         NaN
# 1                  no         NaN         NaN         NaN         NaN
# ...

# %%
iris.head()
# Out:
#    Emp_id        Dept  working years  Sales promotion using and  \
# 0  EMP001     FINANCE              5  72704                 yes
# 1  EMP002  OPERATIONS              4  44718                  no
# 2  EMP003       SALES              3  35210                  no
# 3  EMP004     FINANCE              5  30681                 yes
# 4  EMP005  OPERATIONS              6  47487                  no
#
#   promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                yes         NaN         NaN         NaN         NaN
# 1                 no         NaN         NaN         NaN         NaN
# 2                 no         NaN         NaN         NaN         NaN
# 3                yes         NaN         NaN         NaN         NaN
# 4                yes         NaN         NaN         NaN         NaN
#
#    Unnamed: 10    Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0          NaN            NaN         NaN         NaN
# 1          NaN  use of and/or         NaN         NaN
# ...

# %%
iris.drop([5,6],axis=0)
# Out:
#     Emp_id        Dept  working years   Sales promotion using and  \
# 0   EMP001     FINANCE              5   72704                 yes
# 1   EMP002  OPERATIONS              4   44718                  no
# 2   EMP003       SALES              3   35210                  no
# 3   EMP004     FINANCE              5   30681                 yes
# 4   EMP005  OPERATIONS              6   47487                  no
# 7   EMP008     FINANCE              5   38966                 yes
# 8   EMP009  OPERATIONS              6   77052                  no
# 9   EMP010       SALES              2   86570                  no
# 10  EMP011       SALES              3   30250                  no
# 11  EMP012  OPERATIONS              7  100000                  no
#
#    promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                 yes         NaN         NaN         NaN         NaN
# 1                  no         NaN         NaN         NaN         NaN
# ...

# %%
iris.head(10)
# Out:
#    Emp_id        Dept  working years  Sales promotion using and  \
# 0  EMP001     FINANCE              5  72704                 yes
# 1  EMP002  OPERATIONS              4  44718                  no
# 2  EMP003       SALES              3  35210                  no
# 3  EMP004     FINANCE              5  30681                 yes
# 4  EMP005  OPERATIONS              6  47487                  no
# 5  EMP006  OPERATIONS              2  75613                  no
# 6  EMP007       SALES              3  63671                  no
# 7  EMP008     FINANCE              5  38966                 yes
# 8  EMP009  OPERATIONS              6  77052                  no
# 9  EMP010       SALES              2  86570                  no
#
#   promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                yes         NaN         NaN         NaN         NaN
# 1                 no         NaN         NaN         NaN         NaN
# ...

# %%
def double(s):
    return s*2

# %%
iris[['Sales']].apply(double)
# Out:
#      Sales
# 0   145408
# 1    89436
# 2    70420
# 3    61362
# 4    94974
# 5   151226
# 6   127342
# 7    77932
# 8   154104
# 9   173140
# 10   60500
# 11  200000

# %%
iris['Dept'].value_counts()
# Out:
# Dept
# OPERATIONS    5
# SALES         4
# FINANCE       3
# Name: count, dtype: int64

# %%
iris.sort_values(by="Dept")
# Out:
#     Emp_id        Dept  working years   Sales promotion using and  \
# 0   EMP001     FINANCE              5   72704                 yes
# 3   EMP004     FINANCE              5   30681                 yes
# 7   EMP008     FINANCE              5   38966                 yes
# 1   EMP002  OPERATIONS              4   44718                  no
# 4   EMP005  OPERATIONS              6   47487                  no
# 5   EMP006  OPERATIONS              2   75613                  no
# 8   EMP009  OPERATIONS              6   77052                  no
# 11  EMP012  OPERATIONS              7  100000                  no
# 2   EMP003       SALES              3   35210                  no
# 6   EMP007       SALES              3   63671                  no
# 9   EMP010       SALES              2   86570                  no
# 10  EMP011       SALES              3   30250                  no
#
#    promotion using or  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...
