# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ipl=pd.read_csv('matches.csv')

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
ipl.tail(10)
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1085  1426300   2024  Bengaluru  2024-05-12       League          C Green
# 1086  1426302   2024      Delhi  2024-05-14       League         I Sharma
# 1087  1426303   2024   Guwahati  2024-05-15       League        SM Curran
# 1088  1426305   2024     Mumbai  2024-05-17       League         N Pooran
# 1089  1426306   2024  Bengaluru  2024-05-18       League     F du Plessis
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1085                   M Chinnaswamy Stadium, Bengaluru
# ...

# %%
ipl.shape
# Out:
# (1095, 20)

# %%
ipl.size
# Out:
# 21900

# %%
ipl['player_of_match'].value_counts()
# Out:
# player_of_match
# AB de Villiers       25
# CH Gayle             22
# RG Sharma            19
# DA Warner            18
# V Kohli              18
#                      ..
# NV Ojha               1
# KV Sharma             1
# Washington Sundar     1
# PD Collingwood        1
# Shahbaz Ahmed         1
# Name: count, Length: 291, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:1]
# Out:
# player_of_match
# AB de Villiers    25
# Name: count, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:10].keys()
# Out:
# Index(['AB de Villiers', 'CH Gayle', 'RG Sharma', 'DA Warner', 'V Kohli',
#        'MS Dhoni', 'SR Watson', 'YK Pathan', 'RA Jadeja', 'AD Russell'],
#       dtype='object', name='player_of_match')

# %%
plt.figure(figsize=(8,5))
plt.bar(list(ipl['player_of_match'].value_counts()[0:5].keys()),list(ipl['player_of_match'].value_counts()[0:5]),color='r')
plt.show()

# %%
ipl['result'].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
ipl['toss_winner'].value_counts()[0:1]
# Out:
# toss_winner
# Mumbai Indians    143
# Name: count, dtype: int64

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
batting_first=ipl[ipl['result']!='wickets']

# %%
batting_first.head()
# Out:
#         id   season        city        date match_type player_of_match  \
# 0   335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1   335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 7   335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 9   335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
# 14  335996  2007/08   Bangalore  2008-04-28     League        MS Dhoni
#
#                                          venue                        team1  \
# 0                        M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1   Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 7              MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 9   Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 14                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  \
# ...

# %%
plt.figure(figsize=(5,5))
plt.hist(batting_first['result'])
plt.title("Distribution of runs")
plt.ylabel("runs")
plt.show()

# %%
batting_first['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 73
# Chennai Super Kings            71
# Kolkata Knight Riders          55
# Royal Challengers Bangalore    55
# Rajasthan Royals               45
# Sunrisers Hyderabad            45
# Kings XI Punjab                43
# Delhi Daredevils               25
# Delhi Capitals                 24
# Deccan Chargers                18
# Lucknow Super Giants           16
# Gujarat Titans                 11
# Punjab Kings                   11
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Royal Challengers Bengaluru     4
# Rising Pune Supergiants         2
# Kochi Tuskers Kerala            2
# Gujarat Lions                   1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
plt.bar(list(batting_first['winner'].value_counts()[0:3].keys()),list(batting_first['winner'].value_counts()[0:3]),color=["g",'y','r'])
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(batting_first['winner'].value_counts()),labels=list(batting_first['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
batting_second=ipl[ipl['result']!='runs']

# %%
batting_second.head()
# Out:
#        id   season       city        date match_type player_of_match  \
# 2  335984  2007/08      Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08     Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08    Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08     Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08  Hyderabad  2008-04-22     League        V Sehwag
#
#                                        venue                  team1  \
# 2                           Feroz Shah Kotla       Delhi Daredevils
# 3                           Wankhede Stadium         Mumbai Indians
# 4                               Eden Gardens  Kolkata Knight Riders
# 5                     Sawai Mansingh Stadium       Rajasthan Royals
# 6  Rajiv Gandhi International Stadium, Uppal        Deccan Chargers
#
#                          team2       toss_winner toss_decision  \
# 2             Rajasthan Royals  Rajasthan Royals           bat
# ...

# %%
batting_second.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1087  1426303   2024   Guwahati  2024-05-15       League        SM Curran
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1087                Barsapara Cricket Stadium, Guwahati
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1087             Rajasthan Royals           Punjab Kings     Rajasthan Royals
# ...

# %%
plt.figure(figsize=(4,4))
plt.hist(batting_second['result'],bins=3)
plt.show()

# %%
batting_second['winner'].value_counts()
# Out:
# winner
# Kolkata Knight Riders          77
# Mumbai Indians                 73
# Rajasthan Royals               69
# Chennai Super Kings            67
# Royal Challengers Bangalore    63
# Kings XI Punjab                48
# Sunrisers Hyderabad            44
# Delhi Daredevils               42
# Delhi Capitals                 27
# Gujarat Titans                 17
# Punjab Kings                   13
# Gujarat Lions                  12
# Deccan Chargers                11
# Lucknow Super Giants            8
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Royal Challengers Bengaluru     3
# Name: count, dtype: int64

# %%
batting_second['result'].value_counts()
# Out:
# result
# wickets      578
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
batting_second['result'].value_counts()[0:4]
# Out:
# result
# wickets      578
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
plt.bar(list(batting_second['winner'].value_counts()[0:3].keys()),list(batting_second['winner'].value_counts()[0:3]),color=["g",'y','r'])
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(batting_second['winner'].value_counts()),labels=list(batting_second['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
ipl['season'].value_counts()
# Out:
# season
# 2013       76
# 2023       74
# 2012       74
# 2022       74
# 2011       73
# 2024       71
# 2018       60
# 2021       60
# 2020/21    60
# 2019       60
# 2016       60
# 2014       60
# 2009/10    60
# 2017       59
# 2015       59
# 2007/08    58
# 2009       57
# Name: count, dtype: int64

# %%
ipl['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
import numpy as np
np.sum(ipl['toss_winner']==ipl['winner'])
# Out:
# 554
