# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file=pd.read_csv('players_20.csv')

# %%
file.shape
# Out:
# (18483, 110)

# %%
file.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, CF, ST
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 2          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 3          E. Hazard                          Eden Hazard           LW, CF
# 4       K. De Bruyne                      Kevin De Bruyne          CAM, CM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
file.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18478     252568  https://sofifa.com/player/252568/mohammed-saga...
# 18479     252883  https://sofifa.com/player/252883/hector-kypria...
# 18480     252890  https://sofifa.com/player/252890/brandon-mcphe...
# 18481     252891  https://sofifa.com/player/252891/joseph-hope/2...
# 18482     252893  https://sofifa.com/player/252893/cameron-paint...
#
#          short_name                 long_name player_positions  overall  \
# 18478      M. Sagaf   Mohammed Ali Omar Sagaf               CM       48
# 18479  H. Kyprianou  Hector Matthew Kyprianou               CM       48
# 18480  B. McPherson         Brandon McPherson               RM       48
# 18481       J. Hope     Joseph Alexander Hope               LB       48
# 18482    C. Painter           Cameron Painter              CDM       48
#
#        potential  value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
file.size
# Out:
# 2033130

# %%
for col in file.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# player_positions
# overall
# potential
# value_eur
# wage_eur
# age
# dob
# height_cm
# weight_kg
# club_team_id
# club_name
# league_name
# league_level
# club_position
# club_jersey_number
# club_loaned_from
# club_joined
# club_contract_valid_until
# nationality_id
# nationality_name
# nation_team_id
# nation_position
# nation_jersey_number
# preferred_foot
# weak_foot
# skill_moves
# international_reputation
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# player_traits
# pace
# shooting
# passing
# dribbling
# defending
# physic
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# ...

# %%
file['nationality_name'].value_counts()
# Out:
# nationality_name
# England        1670
# Germany        1218
# Spain          1045
# France         1004
# Argentina       886
#                ...
# Puerto Rico       1
# Eritrea           1
# Bahrain           1
# Chad              1
# Indonesia         1
# Name: count, Length: 162, dtype: int64

# %%
file['nationality_name'].value_counts()[0:10]
# Out:
# nationality_name
# England        1670
# Germany        1218
# Spain          1045
# France         1004
# Argentina       886
# Brazil          827
# Italy           732
# Colombia        612
# Japan           479
# Netherlands     416
# Name: count, dtype: int64

# %%
file['nationality_name'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object', name='nationality_name')

# %%
plt.figure(figsize=(5,5))
plt.bar(list(file['nationality_name'].value_counts()[0:5].keys()),list(file['nationality_name'].value_counts()[0:5]),color='g')
plt.show()

# %%
player_salary=file[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi  560000.0
# 1  Cristiano Ronaldo  410000.0
# 2          Neymar Jr  290000.0
# 3          E. Hazard  470000.0
# 4       K. De Bruyne  370000.0

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi  560000.0
# 3           E. Hazard  470000.0
# 1   Cristiano Ronaldo  410000.0
# 4        K. De Bruyne  370000.0
# 17       A. Griezmann  370000.0

# %%
plt.figure(figsize=(5,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color=['g','r','b','orange','purple'])
plt.show()

# %%
file['nationality_name']=="Germany"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18478    False
# 18479    False
# 18480    False
# 18481    False
# 18482    False
# Name: nationality_name, Length: 18483, dtype: bool

# %%
germ=file[file['nationality_name']=="Germany"]

# %%
germ.head()
# Out:
#     sofifa_id                                         player_url  \
# 7      192448  https://sofifa.com/player/192448/marc-andre-te...
# 25     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 30     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 31     188350  https://sofifa.com/player/188350/marco-reus/20...
# 45     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name player_positions  overall  potential  \
# 7   M. ter Stegen  Marc-André ter Stegen               GK       90         93
# 25       M. Neuer     Manuel Peter Neuer               GK       88         88
# 30       T. Kroos             Toni Kroos               CM       88         88
# 31        M. Reus             Marco Reus      CAM, LM, ST       88         88
# 45     M. Hummels           Mats Hummels               CB       87         87
#
#      value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
germ.sort_values(by=['potential'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 7       192448  https://sofifa.com/player/192448/marc-andre-te...
# 71      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 155     235790  https://sofifa.com/player/235790/kai-havertz/2...
# 98      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 147     212194  https://sofifa.com/player/212194/julian-brandt...
#
#         short_name              long_name player_positions  overall  \
# 7    M. ter Stegen  Marc-André ter Stegen               GK       90
# 71         L. Sané        Leroy Aziz Sané               LW       86
# 155     K. Havertz      Kai Lukas Havertz          CAM, RM       84
# 98         N. Süle            Niklas Süle               CB       85
# 147      J. Brandt          Julian Brandt      CAM, LM, RM       84
#
#      potential   value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# 7           93  67500000.0  250000.0   27  ...  33+3  33+3  33+3  31+3  88+3
# ...

# %%
germ.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 30      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 7       192448  https://sofifa.com/player/192448/marc-andre-te...
# 71      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 126     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 31      188350  https://sofifa.com/player/188350/marco-reus/20...
#
#         short_name              long_name player_positions  overall  \
# 30        T. Kroos             Toni Kroos               CM       88
# 7    M. ter Stegen  Marc-André ter Stegen               GK       90
# 71         L. Sané        Leroy Aziz Sané               LW       86
# 126    İ. Gündoğan         İlkay Gündoğan          CM, CDM       84
# 31         M. Reus             Marco Reus      CAM, LM, ST       88
#
#      potential   value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# 30          88  57000000.0  330000.0   29  ...  70+3  70+3  70+3  72+3  18+3
# ...

# %%
germ[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur
# 30        T. Kroos  330000.0
# 7    M. ter Stegen  250000.0
# 71         L. Sané  195000.0
# 126    İ. Gündoğan  180000.0
# 31         M. Reus  165000.0

# %%
player_shooting=file[['short_name','shooting']]

# %%
player_shooting.head()
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3          E. Hazard      83.0
# 4       K. De Bruyne      86.0

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#            short_name  shooting
# 1   Cristiano Ronaldo      93.0
# 0            L. Messi      92.0
# 19            H. Kane      91.0
# 11          S. Agüero      90.0
# 13          L. Suárez      89.0

# %%
player_defending=file[['short_name','defending']]

# %%
player_defending.head()
# Out:
#           short_name  defending
# 0           L. Messi       39.0
# 1  Cristiano Ronaldo       35.0
# 2          Neymar Jr       32.0
# 3          E. Hazard       35.0
# 4       K. De Bruyne       61.0

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending
# 10  G. Chiellini       90.0
# 8    V. van Dijk       90.0
# 29      D. Godín       89.0
# 45    M. Hummels       89.0
# 18  K. Koulibaly       89.0
