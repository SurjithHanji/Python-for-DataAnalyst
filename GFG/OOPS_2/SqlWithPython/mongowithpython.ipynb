# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.14.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.14.1-cp312-cp312-win_amd64.whl (904 kB)
#    ---------------------------------------- 0.0/904.5 kB ? eta -:--:--
#    ---------------------------------- ----- 786.4/904.5 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 904.5/904.5 kB 5.1 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient

# %%
client=MongoClient()

# %%
client = MongoClient("mongodb://localhost:27017/")

# %%
from pymongo import MongoClient
client=MongoClient()

client = MongoClient("mongodb://localhost:27017/")

mydb = client['my_database']
mycollection = mydb['myTable']

record = {
title: 'MongoDB and Python', 
description: 'MongoDB is no SQL database', 
tags: ['mongodb', 'database', 'NoSQL'], 
viewers: 104 
}

rec = mydb.myTable.insert(record)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       6 mydb = client['my_database']
#       7 mycollection = mydb['myTable']
#       9 record = {
# ---> 10 title: 'MongoDB and Python',
#      11 description: 'MongoDB is no SQL database',
#      12 tags: ['mongodb', 'database', 'NoSQL'],
#      13 viewers: 104
#      14 }
#      16 rec = mydb.myTable.insert(record)
#
# NameError: name 'title' is not defined
