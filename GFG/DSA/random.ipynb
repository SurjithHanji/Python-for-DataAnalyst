# %%
import random
a = [1, 2, 3, 4, 5, 6]
print(random.choice(a))
# Out:
# 5

# %%
import random
random.seed(5)
print(random.random())
print(random.random())
# Out:
# 0.6229016948897019
# 0.7417869892607294

# %%
#fenerate random numbers in range 

r1=random.randint(10,18)
print(r1)
# Out:
# 18

# %%
#Example 4: Generate a Random Float Between 0 and 1
from random import random 
print(random())
# Out:
# 0.029005228283614737

# %%
#: Randomly Select from List, String, and Tuple
import random

a = [1, 2, 3, 4, 5, 6]
print(random.choice(a))

s = "geeks"
print(random.choice(s))

tup = (1, 2, 3, 4, 5)
print(random.choice(tup))
# Out:
# 4
# e
# 1

# %%
 # Select Multiple Unique Random Items
from random import sample

a = [1, 2, 3, 4, 5, 6]
print(sample(a,3))

s = "geeks"
print(sample(s,2))

tup = (1, 2, 3, 4, 5)
print(sample(tup,3))
# Out:
# [2, 1, 3]
# ['k', 'e']
# [4, 1, 3]

# %%
# : Shuffle Elements in a List

import random
a = [1, 2, 3, 4, 5]

random.shuffle(a)
print("After shuffle : ")
print(a)

random.shuffle(a)
print("\nSecond shuffle : ")
print(a)
# Out:
# After shuffle :
# [5, 4, 3, 1, 2]
#
# Second shuffle :
# [2, 4, 5, 3, 1]

# %% [markdown]
# **Date and Time**

# %%
from datetime import date
d=date(1996,12,11)
print(d)
# Out:
# 1996-12-11

# %%
t=date.today()
print(t)
# Out:
# 2025-09-07

# %%
from datetime import date
t = date.today()
print(t.year)
print(t.month)
print(t.day)
# Out:
# 2025
# 9
# 7

# %%
from datetime import datetime
date_time = datetime.fromtimestamp(1887639468)
print(date_time)
print(date_time.date())
# Out:
# 2029-10-25 21:47:48
# 2029-10-25

# %%
from datetime import date
t = date.today()
date_str = t.isoformat()
print(date_str)
print(type(date_str))
# Out:
# 2025-09-07
# <class 'str'>

# %%
from datetime import time

# Create time object with hour, minute and second
my_time = time(13, 24, 56)
print("Entered time:", my_time)

# Time object with only minute specified
my_time = time(minute=12)
print("Time with one argument:", my_time)

# Time object with default (00:00:00)
my_time = time()
print("Time without argument:", my_time)

# time(hour=26)      → ValueError: hour must be in 0..23
# time(hour='23')    → TypeError: string passed instead of int
# Out:
# Entered time: 13:24:56
# Time with one argument: 00:12:00
# Time without argument: 00:00:00

# %%
from datetime import time

Time = time(11, 34, 56)
print("hour =", Time.hour)
print("minute =", Time.minute)
print("second =", Time.second)
print("microsecond =", Time.microsecond)
# Out:
# hour = 11
# minute = 34
# second = 56
# microsecond = 0

# %%
from datetime import time

# Creating Time object
Time = time(12,24,36,1212)

# Converting Time object to string
Str = Time.isoformat()
print("String Representation:", Str)
print(type(Str))
# Out:
# String Representation: 12:24:36.001212
# <class 'str'>

# %%
from datetime import datetime

# Initializing constructor
a = datetime(1999, 12, 12)
print(a)

# Initializing constructor with time parameters as well
a = datetime(1999, 12, 12, 12, 12, 12, 342380)
print(a)
# Out:
# 1999-12-12 00:00:00
# 1999-12-12 12:12:12.342380

# %%
from datetime import datetime

a = datetime(1999, 12, 12, 12, 12, 12)
print("year =", a.year)
print("month =", a.month)
print("hour =", a.hour)
print("minute =", a.minute)
print("timestamp =", a.timestamp())
# Out:
# year = 1999
# month = 12
# hour = 12
# minute = 12
# timestamp = 944980932.0

# %%
from datetime import datetime

# Calling now() function
today = datetime.now()
print("Current date and time is", today)
# Out:
# Current date and time is 2025-09-07 22:56:41.114748

# %%
from datetime import datetime as dt

# Getting current date and time
now = dt.now()
string = dt.isoformat(now)
print(string)
print(type(string))
# Out:
# 2025-09-07T22:56:47.146043
# <class 'str'>

# %%
from datetime import datetime, timedelta

# Get the current date and time
now = datetime.now()
print("Current Date & Time:", now)

# Add 2 years (approx. 730 days)
after_2_years = now + timedelta(days=730)
print("After 2 Years:", after_2_years)

# Add 2 days
after_2_days = now + timedelta(days=2)
print("After 2 Days:", after_2_days)
# Out:
# Current Date & Time: 2025-09-07 22:56:56.305255
# After 2 Years: 2027-09-07 22:56:56.305255
# After 2 Days: 2025-09-09 22:56:56.305255

# %%
from datetime import datetime, timedelta

# Current date and time
now = datetime.now()
print("Current Time:", now)

# New time after 2 days
new_time = now + timedelta(days=2)
print("New Time (+2 days):", new_time)

# Time difference
print("Time Difference:", new_time - now)
# Out:
# Current Time: 2025-09-07 22:57:07.833335
# New Time (+2 days): 2025-09-09 22:57:07.833335
# Time Difference: 2 days, 0:00:00
